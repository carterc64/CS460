# %%
# !git clone https://github.com/huanghoujing/AlignedReID-Re-Production-Pytorch.git
# Out:
# Cloning into 'AlignedReID-Re-Production-Pytorch'...
# remote: Enumerating objects: 274, done.
# remote: Total 274 (delta 0), reused 0 (delta 0), pack-reused 274
# Receiving objects: 100% (274/274), 137.87 KiB | 750.00 KiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %%
# !unzip /content/market1501-20231122T131747Z-001.zip -d /content/Dataset
# Out:
# Archive:  /content/market1501-20231122T131747Z-001.zip
#   inflating: /content/Dataset/market1501/partitions.pkl
#   inflating: /content/Dataset/market1501/ori_to_new_im_name.pkl
#   inflating: /content/Dataset/market1501/images.tar.gz

# %%
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/AlignedReID-Re-Production-Pytorch
# Out:
# /content/AlignedReID-Re-Production-Pytorch

# %%
# !pwd
# Out:
# /content/AlignedReID-Re-Production-Pytorch

# %%
# !python /content/AlignedReID-Re-Production-Pytorch/script/experiment/train.py -d '(0,)' --dataset market1501 --normalize_feature false -glw 1 -llw 0 -idlw 0 --only_test true --exp_dir experiment --model_weight_file model_weight.pth
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': 'experiment/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'exp_decay_at_epoch': 76,
#  'exp_dir': 'experiment',
#  'g_loss_weight': 1.0,
#  'global_margin': 0.3,
#  'id_loss_weight': 0.0,
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'l_loss_weight': 0.0,
#  'local_conv_out_channels': 128,
#  'local_dist_own_hard_sample': False,
#  'local_margin': 0.3,
#  'log_steps': 10000000000.0,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'model_weight_file': 'model_weight.pth',
#  'normalize_feature': False,
#  'only_test': True,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
# ...
